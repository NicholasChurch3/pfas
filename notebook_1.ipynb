# %%
import pandas as pd

# %%
file_path = "datasets/municipal_pfas_sampling.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#              X            Y  OBJECTID    PWS_ID  \
# 0  655952.9999  267104.1875      4982  26802094
# 1  366177.9375  480195.7813      7349  61702630
# 2  678005.3124  384163.0312     16588  43604275
# 3  431692.8749  394818.0937     17493  63203261
# 4  450354.7813  277497.3125     36022  12201112
#
#                                PWS_NAME        CITY  DS_RO_SEQ_NO  MCD_CODE  \
# 0                  MUKWONAGO WATERWORKS   MUKWONAGO        139193      16.0
# 1          DOWNSVILLE SANITARY DISTRICT  DOWNSVILLE        145500       NaN
# 2                       KIEL WATERWORKS        KIEL        141745      41.0
# 3  TOWN OF FARMINGTON SANITARY DISTRICT     MINDORO        145907       NaN
# 4                 MOUNT HOPE WATERWORKS  MOUNT HOPE        135604      38.0
#
#    MUNI_TYPE_CODE  SURVEY_TOWNSHIP  SURVEY_RANGE  SURVEY_RANGE_NDIR  \
# 0             0.0                5            18                  4
# 1             NaN               27            13                  2
# ...
